# %%
import LanusStats as ls
import requests
import json
import os
from datetime import datetime
import time
import pandas as pd

sofascore = ls.SofaScore()

pd.set_option('display.max_column', None)

# %%
pages = ls.get_available_pages()
print(pages)
leagues = ls.get_available_leagues('Sofascore')
print(leagues)
seasons = ls.get_available_season_for_leagues('Sofascore', 'Colombia Primera A Apertura')
print(seasons)

type_player = ["Midfielders", "Defenders", "Goalkeepers", "Forwards"]
# Out:
# dict_keys(['Fbref', 'Sofascore', '365Scores', 'Fotmob', 'Transfermarkt', 'DataFactory'])
# ['Argentina Liga Profesional', 'Argentina Copa de la Liga Profesional', 'Argentina Primera Nacional', 'Brasileirão Série A', 'Bolivia Division Profesional', 'Chile Primera Division', 'Colombia Primera A Apertura', 'Colombia Primera A Clausura', 'Ecuador LigaPro', 'Mexico LigaMX Apertura', 'Mexico LigaMX Clausura', 'Peru Liga 1', 'Uruguay Primera Division', 'Venezuela Primera Division', 'World Cup', 'Euros', 'Copa America', 'Premier League', 'La Liga', 'Bundesliga', 'Serie A', 'Ligue 1', 'Copa Libertadores', 'Copa Sudamericana', 'MLS', 'Saudi Pro League', 'J1 League', 'NSWL', 'USL Championship', 'La Liga 2']
# {'id': 11539, 'seasons': {'2022': 40320, '2023': 48283, '2024': 57374, '2025': 70681}}

# %%
tt = sofascore.scrape_league_stats(league="Colombia Primera A Apertura", season="2025", save_csv=False, accumulation="per90", selected_positions= ["Goalkeepers"])
# Out:
# could not detect version_main.therefore, we are assuming it is chrome 108 or higher
# End of the pages

# %%
# Ruta donde se guardarán los CSVs (modifica esto)
output_dir = "C:/Users/Mateo/Desktop/Soccer/Futbol-R-Python-Quarto/Python/data/output"

# Crear carpeta si no existe
os.makedirs(output_dir, exist_ok=True)

# Lista de temporadas y tipos de jugador
seasons = [
    # "2022",
    # "2023",
    # "2024",
      "2025"
          ]
type_player = [
    # "Midfielders",
    #  "Defenders",
    #  "Goalkeepers",
      "Forwards"
      ]

# Fecha actual para nombrar los archivos
fecha_actual = datetime.now().strftime("%Y-%m-%d")
# Loop para scrapear y guardar CSV
for season in seasons:
    for position in type_player:
        try:
            df = sofascore.scrape_league_stats(
                league="Colombia Primera A Apertura",
                season=season,
                save_csv=False,
                accumulation="per90",
                selected_positions=[position]
            )

            if df is not None and not df.empty:
                filename = f"Colombia_Primera_A_Apertura_{season}_{position}_{fecha_actual}.csv"
                filepath = os.path.join(output_dir, filename)
                df.to_csv(filepath, index=False)
                print(f"Guardado: {filepath}")
            else:
                print(f"Sin datos para {season} - {position}")

        except Exception as e:
            print(f"Error con {season} - {position}: {e}")

        # Pausa para evitar sobrecargar el servidor
        time.sleep(2)  # puedes aumentar a 3, 5, etc. si hace falta
# Out:
# could not detect version_main.therefore, we are assuming it is chrome 108 or higher
# End of the pages
# Guardado: C:/Users/Mateo/Desktop/Soccer/Futbol-R-Python-Quarto/Python/data/output\Colombia_Primera_A_Apertura_2025_Forwards_2025-06-12.csv

# %%
df = sofascore.get_players_match_stats("https://www.sofascore.com/football/match/boyaca-chico-fc-atletico-bucaramanga/dxcshxc#id:13320341")
# Out:
# could not detect version_main.therefore, we are assuming it is chrome 108 or higher

# %%
df1 = df[0]
df2 = df[1]

df1 = df1.loc[:, ~df1.columns.duplicated()]
df2 = df2.loc[:, ~df2.columns.duplicated()]

# df1.head(2)
# print(df2.columns)
# print(df1.columns)

# # Para df1
# duplicadas_df1 = df1.columns[df1.columns.duplicated()]
# print("Columnas duplicadas en df1:")
# print(duplicadas_df1)

# # Para df2
# duplicadas_df2 = df2.columns[df2.columns.duplicated()]
# print("Columnas duplicadas en df2:")
# print(duplicadas_df2)

df3 = pd.concat([df1, df2], ignore_index=True, sort=False)

# df3 = pd.concat([df1, df2], ignore_index=True)

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36",
    "Accept": "application/json, text/plain, */*",
    "Cache-Control": "public, max-age=300",
    "X-Client-Version": "production:9574079b5bff3c8ab725e1989963fb3121f67e2f-undefined",
    "X-Mas": "",
}

url = "https://www.sofascore.com/api/v1/unique-tournament/11539/season/70681/events/round/1"

response = requests.get(url, headers=headers)
json_data = response.json()

# json_data
# Extraer todos los IDs
# ids = [event["id"] for event in json_data.get("events", [])]
# customId = [event["customId"] for event in json_data.get("events", [])]

# for event in json_data.get("events", []):
#     match_id = event.get("id")
#     custom_id = event.get("customId")
#     slug = event.get("slug")  # Necesario para armar la URL completa

#     print(custom_id)
#     print(match_id)

# Mostrar los IDs
# print(ids)
# print(json_data)
json_data
# print(custom_id)
# Out:
# {'events': [{'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'pxcsZXbe',
#    'status': {'code': 60, 'description': 'Postponed', 'type': 'postponed'},
#    'homeTeam': {'id': 504899,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Alianza Valledupar FC',
#     'slug': 'alianza-futbol-club',
#     'shortName': 'Alianza Valledupar',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 6056,
#     'nameCode': 'ALI',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ea1515',
#      'secondary': '#0d2e67',
#      'text': '#0d2e67'}},
#    'awayTeam': {'id': 6115,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Independiente Medellín',
#     'slug': 'independiente-medellin',
#     'shortName': 'Ind. Medellín',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 27890,
#     'nameCode': 'IME',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Индепенденте Меделлин'},
#      'shortNameTranslation': {'ar': 'ميديين'}}},
#    'homeScore': {},
#    'awayScore': {},
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1736903942},
#    'hasGlobalHighlights': False,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13320338,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'alianza-valledupar-fc-independiente-medellin',
#    'startTimestamp': 1737752400,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'lxcsnxc',
#    'status': {'code': 60, 'description': 'Postponed', 'type': 'postponed'},
#    'homeTeam': {'id': 6111,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Deportes Tolima',
#     'slug': 'deportes-tolima',
#     'shortName': 'Tolima',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 25883,
#     'nameCode': 'TOL',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#cc3366',
#      'secondary': '#ffff00',
#      'text': '#ffff00'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Депортес Толима'},
#      'shortNameTranslation': {'ar': 'توليما'}}},
#    'awayTeam': {'id': 6113,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Deportivo Pasto',
#     'slug': 'deportivo-pasto',
#     'shortName': 'Dep. Pasto',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 11910,
#     'nameCode': 'PAS',
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#cc0000',
#      'secondary': '#cc0000',
#      'text': '#cc0000'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Депортиво Пасто'},
#      'shortNameTranslation': {'ar': 'باستو'}}},
#    'homeScore': {},
#    'awayScore': {},
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1736903571},
#    'hasGlobalHighlights': False,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13320346,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'deportivo-pasto-deportes-tolima',
#    'startTimestamp': 1737752400,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'oxcstMK',
#    'status': {'code': 60, 'description': 'Postponed', 'type': 'postponed'},
#    'homeTeam': {'id': 89368,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Fortaleza CEIF',
#     'slug': 'fortaleza-ceif',
#     'shortName': 'Fortaleza',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 9124,
#     'nameCode': 'FOR',
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#d6172b',
#      'secondary': '#1b2062',
#      'text': '#1b2062'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Форталеза ФК'},
#      'shortNameTranslation': {'ar': 'فورتاليزا'}}},
#    'awayTeam': {'id': 6114,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Envigado FC',
#     'slug': 'envigado-fc',
#     'shortName': 'Envigado',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 8620,
#     'nameCode': 'ENV',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ff8019',
#      'secondary': '#ff8019',
#      'text': '#ff8019'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'إنفيجادو إف سي',
#       'ru': 'Энвигадо ФК',
#       'hi': 'एनविगाडो एफसी'},
#      'shortNameTranslation': {}}},
#    'homeScore': {},
#    'awayScore': {},
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1736903449},
#    'hasGlobalHighlights': False,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13320345,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'fortaleza-ceif-envigado-fc',
#    'startTimestamp': 1737752400,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'fxcsmxc',
#    'status': {'code': 60, 'description': 'Postponed', 'type': 'postponed'},
#    'homeTeam': {'id': 6105,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Junior Barranquilla',
#     'slug': 'junior-barranquilla',
#     'shortName': 'Junior Barranquilla',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 49597,
#     'nameCode': 'JUN',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#cc0000',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Джуниор'},
#      'shortNameTranslation': {'ar': 'جونيور'}}},
#    'awayTeam': {'id': 6112,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Deportivo Cali',
#     'slug': 'deportivo-cali',
#     'shortName': 'Dep. Cali',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 21180,
#     'nameCode': 'DCA',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#006600',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Депортиво Кали'},
#      'shortNameTranslation': {'ar': 'كالي'}}},
#    'homeScore': {},
#    'awayScore': {},
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1736903818},
#    'hasGlobalHighlights': False,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13320339,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'deportivo-cali-junior-barranquilla',
#    'startTimestamp': 1737752400,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'AOcsUou',
#    'status': {'code': 60, 'description': 'Postponed', 'type': 'postponed'},
#    'homeTeam': {'id': 48244,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Rionegro Águilas Doradas',
#     'slug': 'rionegro-aguilas-doradas',
#     'shortName': 'Águilas Doradas',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 9191,
#     'nameCode': 'ADR',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffff66',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Рионегро Агилас'},
#      'shortNameTranslation': {'ar': 'أغيلاس دوراداس'}}},
#    'awayTeam': {'id': 6975,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Deportivo La Equidad',
#     'slug': 'deportivo-la-equidad',
#     'shortName': 'La Equidad',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 8864,
#     'nameCode': 'EQU',
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Депортиво Ля Эквидад'},
#      'shortNameTranslation': {'ar': 'لا إيكويداد'}}},
#    'homeScore': {},
#    'awayScore': {},
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1736903696},
#    'hasGlobalHighlights': False,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13320337,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'rionegro-aguilas-doradas-deportivo-la-equidad',
#    'startTimestamp': 1737752400,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'dxcshxc',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 1,
#    'homeTeam': {'id': 6107,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Boyacá Chicó FC',
#     'slug': 'boyaca-chico-fc',
#     'shortName': 'Boyacá Chicó',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 7903,
#     'nameCode': 'CHI',
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#99ff99',
#      'text': '#99ff99'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Бояка Чико'},
#      'shortNameTranslation': {'ar': 'بويكا شيكو'}}},
#    'awayTeam': {'id': 6103,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Atlético Bucaramanga',
#     'slug': 'atletico-bucaramanga',
#     'shortName': 'Bucaramanga',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 23661,
#     'nameCode': 'ABU',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#f9ec00',
#      'secondary': '#f9ec00',
#      'text': '#f9ec00'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Букараманга'},
#      'shortNameTranslation': {'ar': 'بوكارامانغا'}}},
#    'homeScore': {'current': 1,
#     'display': 1,
#     'period1': 1,
#     'period2': 0,
#     'normaltime': 1},
#    'awayScore': {'current': 0,
#     'display': 0,
#     'period1': 0,
#     'period2': 0,
#     'normaltime': 0},
#    'time': {'injuryTime1': 10,
#     'injuryTime2': 6,
#     'currentPeriodStartTimestamp': 1737768803},
#    'changes': {'changes': ['time.injuryTime2',
#      'status.code',
#      'status.description',
#      'status.type'],
#     'changeTimestamp': 1737771989},
#    'hasGlobalHighlights': False,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13320341,
#    'homeRedCards': 1,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'boyaca-chico-fc-atletico-bucaramanga',
#    'startTimestamp': 1737759600,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'cxcszMK',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 1,
#    'homeTeam': {'id': 6102,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'América de Cali',
#     'slug': 'america-de-cali',
#     'shortName': 'América',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 49714,
#     'nameCode': 'AME',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ff0000',
#      'secondary': '#ff0000',
#      'text': '#ff0000'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Америка Кали'},
#      'shortNameTranslation': {'ar': 'أمريكا'}}},
#    'awayTeam': {'id': 89374,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Llaneros FC',
#     'slug': 'llaneros-fc',
#     'shortName': 'Llaneros',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 6396,
#     'nameCode': 'LLA',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#d2b54a',
#      'text': '#d2b54a'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'نادي كرة القدم لانيروس',
#       'ru': 'Льянерос ФК',
#       'hi': 'लैनरोस एफसी'},
#      'shortNameTranslation': {}}},
#    'homeScore': {'current': 4,
#     'display': 4,
#     'period1': 1,
#     'period2': 3,
#     'normaltime': 4},
#    'awayScore': {'current': 3,
#     'display': 3,
#     'period1': 2,
#     'period2': 1,
#     'normaltime': 3},
#    'time': {'injuryTime1': 5,
#     'injuryTime2': 6,
#     'currentPeriodStartTimestamp': 1737846557},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1737849686},
#    'hasGlobalHighlights': False,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13320342,
#    'homeRedCards': 1,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'llaneros-fc-america-de-cali',
#    'startTimestamp': 1737842400,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'gxcstxc',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 1,
#    'homeTeam': {'id': 6106,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Atlético Nacional',
#     'slug': 'atletico-nacional',
#     'shortName': 'Atl. Nacional',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 89301,
#     'nameCode': 'CAN',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#339933',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Насьональ Медельин'},
#      'shortNameTranslation': {'ar': 'أتلتيكو ناسيونال'}}},
#    'awayTeam': {'id': 6118,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Once Caldas',
#     'slug': 'once-caldas',
#     'shortName': 'Once Caldas',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 21257,
#     'nameCode': 'OC',
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Онсе Кальдас'},
#      'shortNameTranslation': {'ar': 'أونس كالداس'}}},
#    'homeScore': {'current': 4,
#     'display': 4,
#     'period1': 1,
#     'period2': 3,
#     'normaltime': 4},
#    'awayScore': {'current': 0,
#     'display': 0,
#     'period1': 0,
#     'period2': 0,
#     'normaltime': 0},
#    'time': {'injuryTime1': 3,
#     'injuryTime2': 0,
#     'currentPeriodStartTimestamp': 1737855535},
#    'changes': {'changes': ['time.injuryTime2',
#      'status.code',
#      'status.description',
#      'status.type'],
#     'changeTimestamp': 1737858271},
#    'hasGlobalHighlights': False,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13320344,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'once-caldas-atletico-nacional',
#    'startTimestamp': 1737851400,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'jxcsqxc',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 1,
#    'homeTeam': {'id': 6116,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Independiente Santa Fe',
#     'slug': 'independiente-santa-fe',
#     'shortName': 'Santa Fe',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 25989,
#     'nameCode': 'SFE',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#ff0033',
#      'text': '#ff0033'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'إنديبيندينت سانتا في',
#       'ru': 'Индепендиенте Санта Фе',
#       'hi': 'इंडिपेंडेंट सांटा फ़े'},
#      'shortNameTranslation': {}}},
#    'awayTeam': {'id': 6109,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Deportivo Pereira',
#     'slug': 'deportivo-pereira',
#     'shortName': 'Deportivo Pereira',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 15588,
#     'nameCode': 'PER',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#d00000',
#      'secondary': '#222226',
#      'text': '#222226'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Депортес Перейра'},
#      'shortNameTranslation': {'ar': 'بيريرا'}}},
#    'homeScore': {'current': 2,
#     'display': 2,
#     'period1': 2,
#     'period2': 0,
#     'normaltime': 2},
#    'awayScore': {'current': 1,
#     'display': 1,
#     'period1': 1,
#     'period2': 0,
#     'normaltime': 1},
#    'time': {'injuryTime1': 4,
#     'injuryTime2': 5,
#     'currentPeriodStartTimestamp': 1737925956},
#    'changes': {'changes': ['time.injuryTime2',
#      'status.code',
#      'status.description',
#      'status.type'],
#     'changeTimestamp': 1737929117},
#    'hasGlobalHighlights': False,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13320343,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'independiente-santa-fe-deportivo-pereira',
#    'startTimestamp': 1737921600,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'fxcsmxc',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 3,
#    'homeTeam': {'id': 6105,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Junior Barranquilla',
#     'slug': 'junior-barranquilla',
#     'shortName': 'Junior Barranquilla',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 49597,
#     'nameCode': 'JUN',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#cc0000',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Джуниор'},
#      'shortNameTranslation': {'ar': 'جونيور'}}},
#    'awayTeam': {'id': 6112,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Deportivo Cali',
#     'slug': 'deportivo-cali',
#     'shortName': 'Dep. Cali',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 21180,
#     'nameCode': 'DCA',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#006600',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Депортиво Кали'},
#      'shortNameTranslation': {'ar': 'كالي'}}},
#    'homeScore': {'current': 0,
#     'display': 0,
#     'period1': 0,
#     'period2': 0,
#     'normaltime': 0},
#    'awayScore': {'current': 0,
#     'display': 0,
#     'period1': 0,
#     'period2': 0,
#     'normaltime': 0},
#    'time': {'injuryTime1': 2,
#     'injuryTime2': 4,
#     'currentPeriodStartTimestamp': 1737933513},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1737936468},
#    'hasGlobalHighlights': False,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13340350,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'deportivo-cali-junior-barranquilla',
#    'startTimestamp': 1737929400,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'pxcsZXbe',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 3,
#    'homeTeam': {'id': 504899,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Alianza Valledupar FC',
#     'slug': 'alianza-futbol-club',
#     'shortName': 'Alianza Valledupar',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 6056,
#     'nameCode': 'ALI',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ea1515',
#      'secondary': '#0d2e67',
#      'text': '#0d2e67'}},
#    'awayTeam': {'id': 6115,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Independiente Medellín',
#     'slug': 'independiente-medellin',
#     'shortName': 'Ind. Medellín',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 27890,
#     'nameCode': 'IME',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Индепенденте Меделлин'},
#      'shortNameTranslation': {'ar': 'ميديين'}}},
#    'homeScore': {'current': 1,
#     'display': 1,
#     'period1': 0,
#     'period2': 1,
#     'normaltime': 1},
#    'awayScore': {'current': 1,
#     'display': 1,
#     'period1': 0,
#     'period2': 1,
#     'normaltime': 1},
#    'time': {'injuryTime1': 8,
#     'injuryTime2': 5,
#     'currentPeriodStartTimestamp': 1737941401},
#    'changes': {'changes': ['time.injuryTime2',
#      'status.code',
#      'status.description',
#      'status.type'],
#     'changeTimestamp': 1737944412},
#    'hasGlobalHighlights': False,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13340351,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'alianza-valledupar-fc-independiente-medellin',
#    'startTimestamp': 1737937200,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'gxcstxc',
#    'status': {'code': 70, 'description': 'Canceled', 'type': 'canceled'},
#    'homeTeam': {'id': 6106,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Atlético Nacional',
#     'slug': 'atletico-nacional',
#     'shortName': 'Atl. Nacional',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 89301,
#     'nameCode': 'CAN',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#339933',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Насьональ Медельин'},
#      'shortNameTranslation': {'ar': 'أتلتيكو ناسيونال'}}},
#    'awayTeam': {'id': 6118,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Once Caldas',
#     'slug': 'once-caldas',
#     'shortName': 'Once Caldas',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 21257,
#     'nameCode': 'OC',
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Онсе Кальдас'},
#      'shortNameTranslation': {'ar': 'أونس كالداس'}}},
#    'homeScore': {},
#    'awayScore': {},
#    'time': {},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1736905854},
#    'hasGlobalHighlights': False,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13340352,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'once-caldas-atletico-nacional',
#    'startTimestamp': 1737937200,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'tournament': {'name': 'Primera A, Apertura',
#     'slug': 'primera-a-apertura',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 283,
#     'isGroup': False,
#     'isLive': False,
#     'id': 19232,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، مرحلة الذهاب',
#       'hi': 'प्राइमेरा ए, अपेर्तुरा',
#       'bn': 'প্রাইমেরা এ, অ্যাপার্টুরা'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'AOcsUou',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 3,
#    'homeTeam': {'id': 48244,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Rionegro Águilas Doradas',
#     'slug': 'rionegro-aguilas-doradas',
#     'shortName': 'Águilas Doradas',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 9191,
#     'nameCode': 'ADR',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffff66',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Рионегро Агилас'},
#      'shortNameTranslation': {'ar': 'أغيلاس دوراداس'}}},
#    'awayTeam': {'id': 6975,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Deportivo La Equidad',
#     'slug': 'deportivo-la-equidad',
#     'shortName': 'La Equidad',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 8864,
#     'nameCode': 'EQU',
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
# ...
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 285,
#     'isGroup': True,
#     'groupName': 'Group A',
#     'isLive': False,
#     'id': 72726,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، ذهاب، المجموعة A',
#       'hi': 'प्राइमेरा ए, एपर्टुरा, ग्रुप ए',
#       'bn': 'প্রিমেরা এ, অ্যাপার্তুরা, গ্রুপ এ'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'fxcslxc',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 3,
#    'homeTeam': {'id': 6105,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Junior Barranquilla',
#     'slug': 'junior-barranquilla',
#     'shortName': 'Junior Barranquilla',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 49597,
#     'nameCode': 'JUN',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#cc0000',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Джуниор'},
#      'shortNameTranslation': {'ar': 'جونيور'}}},
#    'awayTeam': {'id': 6111,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Deportes Tolima',
#     'slug': 'deportes-tolima',
#     'shortName': 'Tolima',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 25883,
#     'nameCode': 'TOL',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#cc3366',
#      'secondary': '#ffff00',
#      'text': '#ffff00'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Депортес Толима'},
#      'shortNameTranslation': {'ar': 'توليما'}}},
#    'homeScore': {'current': 1,
#     'display': 1,
#     'period1': 1,
#     'period2': 0,
#     'normaltime': 1},
#    'awayScore': {'current': 1,
#     'display': 1,
#     'period1': 1,
#     'period2': 0,
#     'normaltime': 1},
#    'time': {'injuryTime1': 2,
#     'injuryTime2': 5,
#     'currentPeriodStartTimestamp': 1748734638},
#    'changes': {'changes': ['time.injuryTime2',
#      'status.code',
#      'status.description',
#      'status.type'],
#     'changeTimestamp': 1748737650},
#    'hasGlobalHighlights': True,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13943314,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'deportes-tolima-junior-barranquilla',
#    'startTimestamp': 1748730600,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'correctAiInsight': False,
#    'tournament': {'name': 'Primera A, Apertura, Group A',
#     'slug': 'primera-a-apertura-group-a',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 285,
#     'isGroup': True,
#     'groupName': 'Group A',
#     'isLive': False,
#     'id': 72726,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، ذهاب، المجموعة A',
#       'hi': 'प्राइमेरा ए, एपर्टुरा, ग्रुप ए',
#       'bn': 'প্রিমেরা এ, অ্যাপার্তুরা, গ্রুপ এ'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'cxcspxc',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 3,
#    'homeTeam': {'id': 6115,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Independiente Medellín',
#     'slug': 'independiente-medellin',
#     'shortName': 'Ind. Medellín',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 27890,
#     'nameCode': 'IME',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#000000',
#      'text': '#000000'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Индепенденте Меделлин'},
#      'shortNameTranslation': {'ar': 'ميديين'}}},
#    'awayTeam': {'id': 6102,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'América de Cali',
#     'slug': 'america-de-cali',
#     'shortName': 'América',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 49714,
#     'nameCode': 'AME',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ff0000',
#      'secondary': '#ff0000',
#      'text': '#ff0000'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Америка Кали'},
#      'shortNameTranslation': {'ar': 'أمريكا'}}},
#    'homeScore': {'current': 1,
#     'display': 1,
#     'period1': 0,
#     'period2': 1,
#     'normaltime': 1},
#    'awayScore': {'current': 1,
#     'display': 1,
#     'period1': 0,
#     'period2': 1,
#     'normaltime': 1},
#    'time': {'injuryTime1': 2,
#     'injuryTime2': 5,
#     'currentPeriodStartTimestamp': 1748742667},
#    'changes': {'changes': ['time.injuryTime2',
#      'status.code',
#      'status.description',
#      'status.type',
#      'homeScore.period2',
#      'homeScore.normaltime',
#      'awayScore.period2',
#      'awayScore.normaltime'],
#     'changeTimestamp': 1748745757},
#    'hasGlobalHighlights': True,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13943315,
#    'awayRedCards': 1,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'independiente-medellin-america-de-cali',
#    'startTimestamp': 1748738700,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'correctAiInsight': True,
#    'tournament': {'name': 'Primera A, Apertura, Group B',
#     'slug': 'primera-a-apertura-group-b',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 284,
#     'isGroup': True,
#     'groupName': 'Group B',
#     'isLive': False,
#     'id': 72727,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، ذهاب، المجموعة B',
#       'hi': 'प्राइमेरा ए, एपर्टुरा, ग्रुप बी',
#       'bn': 'প্রিমেরা এ, অ্যাপার্তুরা, গ্রুপ বি'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'qxcsrxc',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 2,
#    'homeTeam': {'id': 6116,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Independiente Santa Fe',
#     'slug': 'independiente-santa-fe',
#     'shortName': 'Santa Fe',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 25989,
#     'nameCode': 'SFE',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#ff0033',
#      'text': '#ff0033'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'إنديبيندينت سانتا في',
#       'ru': 'Индепендиенте Санта Фе',
#       'hi': 'इंडिपेंडेंट सांटा फ़े'},
#      'shortNameTranslation': {}}},
#    'awayTeam': {'id': 6117,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Millonarios',
#     'slug': 'millonarios',
#     'shortName': 'Millonarios',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 61726,
#     'nameCode': 'MIL',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#0000cc',
#      'secondary': '#0000cc',
#      'text': '#0000cc'},
#     'fieldTranslations': {'nameTranslation': {'ar': 'النادى الرياضي ميلوناريوس',
#       'ru': 'ФК Мильонариос'},
#      'shortNameTranslation': {}}},
#    'homeScore': {'current': 0,
#     'display': 0,
#     'period1': 0,
#     'period2': 0,
#     'normaltime': 0},
#    'awayScore': {'current': 1,
#     'display': 1,
#     'period1': 1,
#     'period2': 0,
#     'normaltime': 1},
#    'time': {'injuryTime1': 4,
#     'injuryTime2': 7,
#     'currentPeriodStartTimestamp': 1748816077},
#    'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#     'changeTimestamp': 1748819545},
#    'hasGlobalHighlights': True,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13943318,
#    'awayRedCards': 1,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'millonarios-independiente-santa-fe',
#    'startTimestamp': 1748811900,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False},
#   {'correctAiInsight': False,
#    'tournament': {'name': 'Primera A, Apertura, Group B',
#     'slug': 'primera-a-apertura-group-b',
#     'category': {'id': 274,
#      'country': {'alpha2': 'CO',
#       'alpha3': 'COL',
#       'name': 'Colombia',
#       'slug': 'colombia'},
#      'name': 'Colombia',
#      'slug': 'colombia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'flag': 'colombia',
#      'alpha2': 'CO'},
#     'uniqueTournament': {'name': 'Primera A, Apertura',
#      'slug': 'primera-a-apertura',
#      'primaryColorHex': '#002c6d',
#      'secondaryColorHex': '#00afcf',
#      'category': {'id': 274,
#       'country': {'alpha2': 'CO',
#        'alpha3': 'COL',
#        'name': 'Colombia',
#        'slug': 'colombia'},
#       'name': 'Colombia',
#       'slug': 'colombia',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'flag': 'colombia',
#       'alpha2': 'CO'},
#      'userCount': 22610,
#      'hasPerformanceGraphFeature': False,
#      'id': 11539,
#      'country': {},
#      'hasEventPlayerStatistics': True,
#      'displayInverseHomeAwayTeams': False,
#      'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأول، مرحلة الذهاب',
#        'hi': 'प्राइमेरा ए, एपर्टुरा',
#        'bn': 'প্রাইমেরা এ, অ্যাপার্তুরা'},
#       'shortNameTranslation': {}}},
#     'priority': 284,
#     'isGroup': True,
#     'groupName': 'Group B',
#     'isLive': False,
#     'id': 72727,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الكولومبي، ذهاب، المجموعة B',
#       'hi': 'प्राइमेरा ए, एपर्टुरा, ग्रुप बी',
#       'bn': 'প্রিমেরা এ, অ্যাপার্তুরা, গ্রুপ বি'},
#      'shortNameTranslation': {}}},
#    'season': {'name': 'Primera A, Apertura 2025',
#     'year': '2025',
#     'editor': False,
#     'id': 70681},
#    'roundInfo': {'round': 1},
#    'customId': 'gxcstxc',
#    'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#    'winnerCode': 3,
#    'homeTeam': {'id': 6106,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Atlético Nacional',
#     'slug': 'atletico-nacional',
#     'shortName': 'Atl. Nacional',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 89301,
#     'nameCode': 'CAN',
#     'disabled': False,
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#339933',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Насьональ Медельин'},
#      'shortNameTranslation': {'ar': 'أتلتيكو ناسيونال'}}},
#    'awayTeam': {'id': 6118,
#     'country': {'alpha2': 'CO',
#      'alpha3': 'COL',
#      'name': 'Colombia',
#      'slug': 'colombia'},
#     'name': 'Once Caldas',
#     'slug': 'once-caldas',
#     'shortName': 'Once Caldas',
#     'gender': 'M',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'userCount': 21257,
#     'nameCode': 'OC',
#     'national': False,
#     'type': 0,
#     'subTeams': [],
#     'teamColors': {'primary': '#ffffff',
#      'secondary': '#ffffff',
#      'text': '#ffffff'},
#     'fieldTranslations': {'nameTranslation': {'ru': 'Онсе Кальдас'},
#      'shortNameTranslation': {'ar': 'أونس كالداس'}}},
#    'homeScore': {'current': 0,
#     'display': 0,
#     'period1': 0,
#     'period2': 0,
#     'normaltime': 0},
#    'awayScore': {'current': 0,
#     'display': 0,
#     'period1': 0,
#     'period2': 0,
#     'normaltime': 0},
#    'time': {'injuryTime1': 5,
#     'injuryTime2': 6,
#     'currentPeriodStartTimestamp': 1748831251},
#    'changes': {'changes': ['time.injuryTime2',
#      'status.code',
#      'status.description',
#      'status.type'],
#     'changeTimestamp': 1748834426},
#    'hasGlobalHighlights': True,
#    'hasEventPlayerStatistics': True,
#    'hasEventPlayerHeatMap': True,
#    'detailId': 1,
#    'crowdsourcingDataDisplayEnabled': False,
#    'id': 13943320,
#    'varInProgress': {'homeTeam': False, 'awayTeam': False},
#    'slug': 'once-caldas-atletico-nacional',
#    'startTimestamp': 1748826900,
#    'finalResultOnly': False,
#    'feedLocked': True,
#    'isEditor': False}],
#  'hasNextPage': False}

# %%
url = "https://www.sofascore.com/api/v1/unique-tournament/11539/season/70681/events/round/1"

response = requests.get(url)
json_data = response.json()

output_folder = os.path.join("..", "data", "output", "matches2")
os.makedirs(output_folder, exist_ok=True)

# Iterar sobre los eventos
for event in json_data.get("events", []):
    match_id = event.get("id")
    custom_id = event.get("customId")
    slug = event.get("slug")  # Necesario para armar la URL completa
    startTimestamp = event.get("startTimestamp")  # Necesario para armar la URL completa

    if match_id and custom_id and slug and startTimestamp:
        match_url = f"https://www.sofascore.com/football/match/{slug}/{custom_id}#id:{match_id}_{startTimestamp}"
        
        # Llamar a la función con esa URL
        print(f"Llamando a: {match_url}")
        # get_players_match_stats = sofascore.get_players_match_stats(match_url)

        # df1 = get_players_match_stats[0]
        # df2 = get_players_match_stats[1]
        
        # df3 = pd.concat(df1, df2)
# Out:
# Llamando a: https://www.sofascore.com/football/match/alianza-valledupar-fc-independiente-medellin/pxcsZXbe#id:13320338_1737752400
# Llamando a: https://www.sofascore.com/football/match/deportivo-pasto-deportes-tolima/lxcsnxc#id:13320346_1737752400
# Llamando a: https://www.sofascore.com/football/match/fortaleza-ceif-envigado-fc/oxcstMK#id:13320345_1737752400
# Llamando a: https://www.sofascore.com/football/match/deportivo-cali-junior-barranquilla/fxcsmxc#id:13320339_1737752400
# Llamando a: https://www.sofascore.com/football/match/rionegro-aguilas-doradas-deportivo-la-equidad/AOcsUou#id:13320337_1737752400
# Llamando a: https://www.sofascore.com/football/match/boyaca-chico-fc-atletico-bucaramanga/dxcshxc#id:13320341_1737759600
# Llamando a: https://www.sofascore.com/football/match/llaneros-fc-america-de-cali/cxcszMK#id:13320342_1737842400
# Llamando a: https://www.sofascore.com/football/match/once-caldas-atletico-nacional/gxcstxc#id:13320344_1737851400
# Llamando a: https://www.sofascore.com/football/match/independiente-santa-fe-deportivo-pereira/jxcsqxc#id:13320343_1737921600
# Llamando a: https://www.sofascore.com/football/match/deportivo-cali-junior-barranquilla/fxcsmxc#id:13340350_1737929400
# Llamando a: https://www.sofascore.com/football/match/alianza-valledupar-fc-independiente-medellin/pxcsZXbe#id:13340351_1737937200
# Llamando a: https://www.sofascore.com/football/match/once-caldas-atletico-nacional/gxcstxc#id:13340352_1737937200
# Llamando a: https://www.sofascore.com/football/match/rionegro-aguilas-doradas-deportivo-la-equidad/AOcsUou#id:13340349_1738018800
# Llamando a: https://www.sofascore.com/football/match/deportivo-pasto-deportes-tolima/lxcsnxc#id:13340348_1738026600
# Llamando a: https://www.sofascore.com/football/match/fortaleza-ceif-envigado-fc/oxcstMK#id:13340346_1738112400
# Llamando a: https://www.sofascore.com/football/match/union-magdalena-millonarios/rxcsBMK#id:13462324_1740094200
# Llamando a: https://www.sofascore.com/football/match/deportes-tolima-junior-barranquilla/fxcslxc#id:13943314_1748730600
# Llamando a: https://www.sofascore.com/football/match/independiente-medellin-america-de-cali/cxcspxc#id:13943315_1748738700
# Llamando a: https://www.sofascore.com/football/match/millonarios-independiente-santa-fe/qxcsrxc#id:13943318_1748811900
# Llamando a: https://www.sofascore.com/football/match/once-caldas-atletico-nacional/gxcstxc#id:13943320_1748826900

# %%
# Crear carpeta si no existe
output_folder = os.path.join("..", "data", "output", "matches2")
os.makedirs(output_folder, exist_ok=True)

round_number = 1

while True:
    url = f"https://www.sofascore.com/api/v1/unique-tournament/11539/season/70681/events/round/{round_number}"
    print(f"\nConsultando: {url}")

    try:
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Error HTTP {response.status_code} en round {round_number}")
            break

        json_data = response.json()
        events = json_data.get("events", [])

        if not events:
            print(f"No hay eventos en round {round_number}. Fin del scraping.")
            break

        for event in events:
            match_id = event.get("id")
            custom_id = event.get("customId")
            slug = event.get("slug")
            startTimestamp = event.get("startTimestamp")


            if match_id and custom_id and slug:
                match_url = f"https://www.sofascore.com/football/match/{slug}/{custom_id}#id:{match_id}"
                print(f"  Llamando a: {match_url}")

                try:
                    get_players_match_stats = sofascore.get_players_match_stats(match_url)

                    if not get_players_match_stats or len(get_players_match_stats) != 2:
                        print(f"  Sin datos para: {match_url}")
                        continue

                    df1, df2 = get_players_match_stats

                    # Eliminar columnas duplicadas
                    df1 = df1.loc[:, ~df1.columns.duplicated()]
                    df2 = df2.loc[:, ~df2.columns.duplicated()]

                    if df1.empty and df2.empty:
                        print(f"  DataFrames vacíos para: {match_url}")
                        continue

                    # Añadir etiqueta de equipo
                    df1["teamType"] = "home"
                    df2["teamType"] = "away"

                    df3 = pd.concat([df1, df2], ignore_index=True, sort=False)

                    output_file = os.path.join(output_folder, f"{slug}_{custom_id}_{match_id}_{startTimestamp}_round_{round_number}.csv")
                    df3.to_csv(output_file, index=False)
                    print(f"  Guardado: {output_file}")

                except Exception as e:
                    print(f"  Error en {match_url}: {e}")

        time.sleep(2)  # Esperar antes de la siguiente ronda
        round_number += 1

    except Exception as e:
        print(f"Error general en round {round_number}: {e}")
        break
# Out:
# could not detect version_main.therefore, we are assuming it is chrome 108 or higher
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 36
#      33 print(f"  Llamando a: {match_url}")
#      35 try:
# ---> 36     get_players_match_stats = sofascore.get_players_match_stats(match_url)
#      38     if not get_players_match_stats or len(get_players_match_stats) != 2:
#      39         print(f"  Sin datos para: {match_url}")
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\LanusStats\sofascore.py:274, in SofaScore.get_players_match_stats(self, match_url)
#     262 """Returns match data for each player.
#     263
#     264 Args:
#    (...)
#     270         the player
#     271 """
#     273 match_id = self.get_match_id(match_url)
# --> 274 home_name, away_name = self.get_team_names(match_url)
#     276 request_url = f'api/v1/event/{match_id}/lineups'
#     278 response = self.sofascore_request(request_url)
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\LanusStats\sofascore.py:310, in SofaScore.get_team_names(self, match_url)
#     300 def get_team_names(self, match_url):
#     301     """Get the team names for the home and away teams
#     302
#     303     Args:
#    (...)
#     307         strings: Name of home and away team.
#     308     """
# --> 310     data = self.get_match_data(match_url)
#     312     try:
#     313         home_team = data['event']['homeTeam']['name']
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\LanusStats\sofascore.py:138, in SofaScore.get_match_data(self, match_url)
#     134 match_id = self.get_match_id(match_url)
#     136 url = f'api/v1/event/{match_id}'
# --> 138 data = self.sofascore_request(url)
#     140 time.sleep(get_random_rate_sleep(2, 3))
#     142 return data
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\LanusStats\sofascore.py:118, in SofaScore.sofascore_request(self, path)
#     115 driver.get(path)
#     116 soup = BeautifulSoup(driver.page_source, 'html.parser')
# --> 118 driver.close()
#     120 data = json.loads(soup.text)
#     121 time.sleep(get_random_rate_sleep(3, 5))
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:595, in WebDriver.close(self)
#     588 def close(self) -> None:
#     589     """Closes the current window.
#     590
#     591     Example:
#     592     --------
#     593     >>> driver.close()
#     594     """
# --> 595     self.execute(Command.CLOSE)
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:445, in WebDriver.execute(self, driver_command, params)
#     442     elif "sessionId" not in params:
#     443         params["sessionId"] = self.session_id
# --> 445 response = self.command_executor.execute(driver_command, params)
#     446 if response:
#     447     self.error_handler.check_response(response)
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\selenium\webdriver\remote\remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\selenium\webdriver\remote\remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\urllib3\_request_methods.py:135, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     132     urlopen_kw["body"] = body
#     134 if method in self._encode_url_methods:
# --> 135     return self.request_encode_url(
#     136         method,
#     137         url,
#     138         fields=fields,  # type: ignore[arg-type]
#     139         headers=headers,
#     140         **urlopen_kw,
#     141     )
#     142 else:
#     143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\urllib3\_request_methods.py:182, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     179 if fields:
#     180     url += "?" + urlencode(fields)
# --> 182 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\urllib3\poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\e.rangel\Documents\emra\Futbol-R-Python-Quarto\.venv\lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1368, in HTTPConnection.getresponse(self)
#    1366 try:
#    1367     try:
# -> 1368         response.begin()
#    1369     except ConnectionError:
#    1370         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:317, in HTTPResponse.begin(self)
#     315 # read until we get a non-100 response
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#     319         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:278, in HTTPResponse._read_status(self)
#     277 def _read_status(self):
# --> 278     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     279     if len(line) > _MAXLINE:
#     280         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
