# %%
import LanusStats as ls
import requests
import json
import os
from datetime import datetime
import time
import pandas as pd

sofascore = ls.SofaScore()

# %%
pages = ls.get_available_pages()
print(pages)
leagues = ls.get_available_leagues('Sofascore')
print(leagues)
seasons = ls.get_available_season_for_leagues('Sofascore', 'Colombia Primera A Apertura')
print(seasons)

type_player = ["Midfielders", "Defenders", "Goalkeepers", "Forwards"]
# Out:
# dict_keys(['Fbref', 'Sofascore', '365Scores', 'Fotmob', 'Transfermarkt', 'DataFactory'])
# ['Argentina Liga Profesional', 'Argentina Copa de la Liga Profesional', 'Argentina Primera Nacional', 'Brasileirão Série A', 'Bolivia Division Profesional', 'Chile Primera Division', 'Colombia Primera A Apertura', 'Colombia Primera A Clausura', 'Ecuador LigaPro', 'Mexico LigaMX Apertura', 'Mexico LigaMX Clausura', 'Peru Liga 1', 'Uruguay Primera Division', 'Venezuela Primera Division', 'World Cup', 'Euros', 'Copa America', 'Premier League', 'La Liga', 'Bundesliga', 'Serie A', 'Ligue 1', 'Copa Libertadores', 'Copa Sudamericana', 'MLS', 'Saudi Pro League', 'J1 League', 'NSWL', 'USL Championship', 'La Liga 2']
# {'id': 11539, 'seasons': {'2022': 40320, '2023': 48283, '2024': 57374, '2025': 70681}}

# %%
tt = sofascore.scrape_league_stats(league="Colombia Primera A Apertura", season="2025", save_csv=False, accumulation="per90", selected_positions= ["Goalkeepers"])
# Out:
# could not detect version_main.therefore, we are assuming it is chrome 108 or higher
# End of the pages

# %%
# Ruta donde se guardarán los CSVs (modifica esto)
output_dir = "C:/Users/Mateo/Desktop/Soccer/Futbol-R-Python-Quarto/Python/data/output"

# Crear carpeta si no existe
os.makedirs(output_dir, exist_ok=True)

# Lista de temporadas y tipos de jugador
seasons = [
    # "2022",
    # "2023",
    # "2024",
      "2025"
          ]
type_player = [
    # "Midfielders",
    #  "Defenders",
    #  "Goalkeepers",
      "Forwards"
      ]

# Fecha actual para nombrar los archivos
fecha_actual = datetime.now().strftime("%Y-%m-%d")
# Loop para scrapear y guardar CSV
for season in seasons:
    for position in type_player:
        try:
            df = sofascore.scrape_league_stats(
                league="Colombia Primera A Apertura",
                season=season,
                save_csv=False,
                accumulation="per90",
                selected_positions=[position]
            )

            if df is not None and not df.empty:
                filename = f"Colombia_Primera_A_Apertura_{season}_{position}_{fecha_actual}.csv"
                filepath = os.path.join(output_dir, filename)
                df.to_csv(filepath, index=False)
                print(f"Guardado: {filepath}")
            else:
                print(f"Sin datos para {season} - {position}")

        except Exception as e:
            print(f"Error con {season} - {position}: {e}")

        # Pausa para evitar sobrecargar el servidor
        time.sleep(2)  # puedes aumentar a 3, 5, etc. si hace falta
# Out:
# could not detect version_main.therefore, we are assuming it is chrome 108 or higher
# End of the pages
# Guardado: C:/Users/Mateo/Desktop/Soccer/Futbol-R-Python-Quarto/Python/data/output\Colombia_Primera_A_Apertura_2025_Forwards_2025-06-12.csv

# %%
get_players_match_stats = sofascore.get_players_match_stats("https://www.sofascore.com/football/match/boyaca-chico-fc-atletico-bucaramanga/dxcshxc#id:13320341")
# Out:
# could not detect version_main.therefore, we are assuming it is chrome 108 or higher

# %%
get_players_match_stats[0]
# Out:
#                  name               slug    shortName position jerseyNumber  \
# 0         Darío Denis        dario-denis     D. Denis        G           23
# 1          Yael López         yael-lopez     Y. López        D           22
# 2       Kevin Riascos      kevin-riascos   K. Riascos        D            2
# 3        Frank Lozano       frank-lozano    F. Lozano        M           19
# 4    Jonathan Herrera   jonathan-herrera   J. Herrera        D           18
# 5     Ronald Valencia    ronald-valencia  R. Valencia        F           77
# 6       Kevin Londoño      kevin-londono   K. Londoño        M           27
# 7   Sebastian Salazar  sebastian-salazar   S. Salazar        M            8
# 8    Eduardo Banguero   eduardo-banguero  E. Banguero        D           22
# 9        Jairo Molina       jairo-molina    J. Molina        F            9
# 10    Jacobo Pimentel    jacobo-pimentel  J. Pimentel        F           21
# 11      Delio Ramírez      delio-ramirez   D. Ramírez        M           10
# 12    Jhonier Negrete    jhonier-negrete   J. Negrete        M            7
# 13        Andres Aedo        aedo-andres      A. Aedo        M            6
# 14    Sebastián Colón    sebastian-colon     S. Colón        F           29
# 15    Rogerio Caicedo    rogerio-caicedo   R. Caicedo        G            1
# 16     Arlen Banguero     arlen-banguero  A. Banguero        D           26
# 17      Wilmar Arango      wilmar-arango    W. Arango        M           20
#
#     height  userCount       id  \
# 0    186.0         14   820358
# 1    178.0         33   971249
# 2    188.0         16   986979
# 3    175.0         19  1015686
# 4    177.0          9   819185
# 5    180.0          9  1154914
# 6    180.0         14  1100037
# 7    180.0          9   789908
# 8    177.0         14   963284
# 9    183.0         68   247931
# 10   176.0         12  1017237
# 11   160.0         11  1015661
# 12     NaN          2  2037361
# 13   183.0          8  1427849
# 14   177.0         28  1465840
# 15   187.0          3   942347
# 16     NaN          3  2035889
# 17   170.0          1  1174981
#
#                                               country marketValueCurrency  \
# 0   {'alpha2': 'UY', 'alpha3': 'URY', 'name': 'Uru...                 EUR
# 1   {'alpha2': 'CR', 'alpha3': 'CRI', 'name': 'Cos...                 EUR
# 2   {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 3   {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 4   {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 5   {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 6   {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 7   {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 8   {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 9   {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 10  {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 11  {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 12                                                 {}                 EUR
# 13  {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 14  {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 15  {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 16  {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
# 17  {'alpha2': 'CO', 'alpha3': 'COL', 'name': 'Col...                 EUR
#
#     ...  keyPass dispossessed shotOffTarget clearanceOffLine interceptionWon  \
# 0   ...      NaN          NaN           NaN              NaN             NaN
# 1   ...      NaN          NaN           NaN              NaN             NaN
# 2   ...      1.0          NaN           NaN              NaN             NaN
# 3   ...      NaN          1.0           1.0              1.0             1.0
# 4   ...      NaN          2.0           NaN              NaN             1.0
# 5   ...      2.0          NaN           1.0              NaN             NaN
# 6   ...      1.0          NaN           1.0              NaN             NaN
# 7   ...      NaN          NaN           NaN              NaN             NaN
# 8   ...      NaN          2.0           NaN              NaN             NaN
# 9   ...      NaN          1.0           NaN              NaN             NaN
# 10  ...      1.0          NaN           1.0              NaN             NaN
# 11  ...      NaN          1.0           NaN              NaN             NaN
# 12  ...      NaN          NaN           NaN              NaN             NaN
# 13  ...      NaN          NaN           NaN              NaN             NaN
# 14  ...      NaN          NaN           NaN              NaN             NaN
# 15  ...      NaN          NaN           NaN              NaN             NaN
# 16  ...      NaN          NaN           NaN              NaN             NaN
# 17  ...      NaN          NaN           NaN              NaN             NaN
#
#     accurateCross wasFouled goals  captain             team
# 0             NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 1             NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 2             NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 3             NaN       NaN   NaN     True  Boyacá Chicó FC
# 4             1.0       1.0   NaN      NaN  Boyacá Chicó FC
# 5             3.0       NaN   NaN      NaN  Boyacá Chicó FC
# 6             NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 7             NaN       2.0   NaN      NaN  Boyacá Chicó FC
# 8             NaN       2.0   NaN      NaN  Boyacá Chicó FC
# 9             NaN       2.0   1.0      NaN  Boyacá Chicó FC
# 10            NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 11            NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 12            NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 13            NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 14            NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 15            NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 16            NaN       NaN   NaN      NaN  Boyacá Chicó FC
# 17            NaN       NaN   NaN      NaN  Boyacá Chicó FC
#
# [18 rows x 54 columns]

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36",
    "Accept": "application/json, text/plain, */*",
    "Cache-Control": "public, max-age=300",
    "X-Client-Version": "production:9574079b5bff3c8ab725e1989963fb3121f67e2f-undefined",
    "X-Mas": "",
}

url = "https://www.sofascore.com/api/v1/unique-tournament/11539/season/70681/events/round/16"

response = requests.get(url, headers=headers)
json_data = response.json()

# Extraer todos los IDs
ids = [event["id"] for event in json_data.get("events", [])]
customId = [event["customId"] for event in json_data.get("events", [])]

for event in json_data.get("events", []):
    match_id = event.get("id")
    custom_id = event.get("customId")
    slug = event.get("slug")  # Necesario para armar la URL completa

    print()

# Mostrar los IDs
print(ids)
print(ids)
# Out:
# [13380413, 13380406, 13358726, 13380407, 13380412, 13380410, 13380408, 13380411, 13380414, 13380409]

# %%
import requests

# Suponiendo que ya tienes esta función disponible
# from sofascore import get_players_match_stats

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36",
    "Accept": "application/json, text/plain, */*",
    "Cache-Control": "public, max-age=300",
    "X-Client-Version": "production:9574079b5bff3c8ab725e1989963fb3121f67e2f-undefined",
    "X-Mas": "",
}

url = "https://www.sofascore.com/api/v1/unique-tournament/11539/season/70681/events/round/20"
response = requests.get(url, headers=headers)
json_data = response.json()

# Ruta de salida
# output_folder = r"C:\Users\Mateo\Desktop\Soccer\Futbol-R-Python-Quarto\Python\data\output\matches"

output_folder = "C:/Users/Mateo/Desktop/Soccer/Futbol-R-Python-Quarto/Python/data/output/matches"
os.makedirs(output_folder, exist_ok=True)

# Iterar sobre los eventos
for event in json_data.get("events", []):
    match_id = event.get("id")
    custom_id = event.get("customId")
    slug = event.get("slug")  # Necesario para armar la URL completa

    if match_id and custom_id and slug:
        match_url = f"https://www.sofascore.com/football/match/{slug}/{custom_id}#id:{match_id}"
        
        # Llamar a la función con esa URL
        print(f"Llamando a: {match_url}")
        get_players_match_stats = sofascore.get_players_match_stats(match_url)

        df1 = get_players_match_stats[0]
        df2 = get_players_match_stats[1]
        
        df3 = pd.concat(df1, df2)

        
        # Puedes hacer algo con el resultado si quieres
        # print(get_players_match_stats)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 29
#      27 # Llamar a la función con esa URL
#      28 print(f"Llamando a: {match_url}")
# ---> 29 get_players_match_stats = sofascore.get_players_match_stats(match_url)
#      31 df1 = get_players_match_stats[0]
#      32 df2 = get_players_match_stats[1]
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\sofascore.py:278, in SofaScore.get_players_match_stats(self, match_url)
#     274 home_name, away_name = self.get_team_names(match_url)
#     276 request_url = f'api/v1/event/{match_id}/lineups'
# --> 278 response = self.sofascore_request(request_url)
#     280 names = {'home': home_name, 'away': away_name}
#     281 dataframes = {}
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\sofascore.py:100, in SofaScore.sofascore_request(self, path)
#      89 """Request used to SofaScore
#      90
#      91 Args:
#    (...)
#      95     data: _description_
#      96 """
#      98 path = f"{self.base_url}{path}"
# --> 100 resultado = get_proxy()
#     101 proxy_host = resultado.split(':')[0]
#     102 proxy_port = resultado.split(':')[-1]
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\functions.py:901, in get_proxy()
#     898 clear_output()
#     900 try:
# --> 901     driver.get('https://sslproxies.org/')
#     902     table = driver.find_elements(By.TAG_NAME, 'table')[0]
#     903     df = pd.read_html(table.get_attribute('outerHTML'))[0]
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\undetected_chromedriver\__init__.py:629, in Chrome._configure_headless.<locals>.get_wrapped(*args, **kwargs)
#     520     self.execute_cdp_cmd(
#     521         "Network.setUserAgentOverride",
#     522         {
#    (...)
#     526         },
#     527     )
#     528     self.execute_cdp_cmd(
#     529         "Page.addScriptToEvaluateOnNewDocument",
#     530         {
#    (...)
#     627         },
#     628     )
# --> 629 return orig_get(*args, **kwargs)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\undetected_chromedriver\__init__.py:665, in Chrome.get(self, url)
#     662 def get(self, url):
#     663     # if self._get_cdc_props():
#     664     #     self._hook_remove_cdc_props()
# --> 665     return super().get(url)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:357, in WebDriver.get(self, url)
#     355 def get(self, url: str) -> None:
#     356     """Loads a web page in the current browser session."""
# --> 357     self.execute(Command.GET, {"url": url})
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     343     elif "sessionId" not in params:
#     344         params["sessionId"] = self.session_id
# --> 346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
#     348     self.error_handler.check_response(response)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\remote_connection.py:300, in RemoteConnection.execute(self, command, params)
#     298 data = utils.dump_json(params)
#     299 url = f"{self._url}{path}"
# --> 300 return self._request(command_info[0], url, body=data)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\remote_connection.py:321, in RemoteConnection._request(self, method, url, body)
#     318     body = None
#     320 if self.keep_alive:
# --> 321     response = self._conn.request(method, url, body=body, headers=headers)
#     322     statuscode = response.status
#     323 else:
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     442     response = conn.urlopen(method, url, **kw)
#     443 else:
# --> 444     response = conn.urlopen(method, u.request_uri, **kw)
#     446 redirect_location = redirect and response.get_redirect_location()
#     447 if not redirect_location:
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import requests
import time
import os
from datetime import datetime
import pandas as pd

# from sofascore import get_players_match_stats

output_folder = r"C:\Users\Mateo\Desktop\Soccer\Futbol-R-Python-Quarto\Python\data\output\matches"
os.makedirs(output_folder, exist_ok=True)

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36",
    "Accept": "application/json, text/plain, */*",
    "Cache-Control": "public, max-age=300",
    "X-Client-Version": "production:9574079b5bff3c8ab725e1989963fb3121f67e2f-undefined",
    "X-Mas": "",
}

base_url = "https://www.sofascore.com/api/v1/unique-tournament/11539/season/70681/events/round/"
round_num = 1

while True:
    url = base_url + str(round_num)
    print(f"\n🔄 Procesando round {round_num}...")
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"⚠️ Error HTTP en round {round_num}. Código: {response.status_code}")
        break

    data = response.json()
    events = data.get("events", [])

    if not events:
        print(f"✅ Fin del scraping. No hay más partidos en round {round_num}.")
        break

    for event in events:
        try:
            match_id = event.get("id")
            custom_id = event.get("customId")
            slug = event.get("slug")

            if not all([match_id, custom_id, slug]):
                continue

            match_url = f"https://www.sofascore.com/football/match/{slug}/{custom_id}#id:{match_id}"
            print(f"➡️  Match: {slug}")

            stats_list = sofascore.get_players_match_stats(match_url)

            if isinstance(stats_list, list) and len(stats_list) == 2:
                df_local, df_visitante = stats_list

                if isinstance(df_local, pd.DataFrame) and isinstance(df_visitante, pd.DataFrame):
                    df_match = pd.concat([df_local, df_visitante], ignore_index=True)

                    if not df_match.empty:
                        fecha = datetime.now().strftime("%Y-%m-%d")
                        nombre_archivo = f"match_{slug}_{fecha}.csv"
                        ruta_salida = os.path.join(output_folder, nombre_archivo)

                        df_match.to_csv(ruta_salida, index=False, encoding="utf-8-sig")
                        print(f"💾 Guardado: {nombre_archivo}")
                    else:
                        print(f"⚠️ Sin datos: {match_url}")
                else:
                    print(f"⚠️ Data malformada en: {match_url}")
            else:
                print(f"⚠️ No se encontraron stats para: {match_url}")

            time.sleep(2)

        except Exception as e:
            print(f"❌ Error en partido {event.get('slug', 'sin_slug')}: {e}")
            continue

    round_num += 1
# Out:
# could not detect version_main.therefore, we are assuming it is chrome 108 or higher
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 51
#      48 match_url = f"https://www.sofascore.com/football/match/{slug}/{custom_id}#id:{match_id}"
#      49 print(f"➡️  Match: {slug}")
# ---> 51 stats_list = sofascore.get_players_match_stats(match_url)
#      53 if isinstance(stats_list, list) and len(stats_list) == 2:
#      54     df_local, df_visitante = stats_list
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\sofascore.py:278, in SofaScore.get_players_match_stats(self, match_url)
#     274 home_name, away_name = self.get_team_names(match_url)
#     276 request_url = f'api/v1/event/{match_id}/lineups'
# --> 278 response = self.sofascore_request(request_url)
#     280 names = {'home': home_name, 'away': away_name}
#     281 dataframes = {}
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\sofascore.py:115, in SofaScore.sofascore_request(self, path)
#     112 chrome_options.add_argument('accept-language=en-US,en;q=0.9')
#     114 driver = uc.Chrome(headless=True,use_subprocess=False,option=chrome_options)
# --> 115 driver.get(path)
#     116 soup = BeautifulSoup(driver.page_source, 'html.parser')
#     118 driver.close()
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\undetected_chromedriver\__init__.py:629, in Chrome._configure_headless.<locals>.get_wrapped(*args, **kwargs)
#     520     self.execute_cdp_cmd(
#     521         "Network.setUserAgentOverride",
#     522         {
#    (...)
#     526         },
#     527     )
#     528     self.execute_cdp_cmd(
#     529         "Page.addScriptToEvaluateOnNewDocument",
#     530         {
#    (...)
#     627         },
#     628     )
# --> 629 return orig_get(*args, **kwargs)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\undetected_chromedriver\__init__.py:665, in Chrome.get(self, url)
#     662 def get(self, url):
#     663     # if self._get_cdc_props():
#     664     #     self._hook_remove_cdc_props()
# --> 665     return super().get(url)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:357, in WebDriver.get(self, url)
#     355 def get(self, url: str) -> None:
#     356     """Loads a web page in the current browser session."""
# --> 357     self.execute(Command.GET, {"url": url})
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     343     elif "sessionId" not in params:
#     344         params["sessionId"] = self.session_id
# --> 346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
#     348     self.error_handler.check_response(response)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\remote_connection.py:300, in RemoteConnection.execute(self, command, params)
#     298 data = utils.dump_json(params)
#     299 url = f"{self._url}{path}"
# --> 300 return self._request(command_info[0], url, body=data)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\remote_connection.py:321, in RemoteConnection._request(self, method, url, body)
#     318     body = None
#     320 if self.keep_alive:
# --> 321     response = self._conn.request(method, url, body=body, headers=headers)
#     322     statuscode = response.status
#     323 else:
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     442     response = conn.urlopen(method, url, **kw)
#     443 else:
# --> 444     response = conn.urlopen(method, u.request_uri, **kw)
#     446 redirect_location = redirect and response.get_redirect_location()
#     447 if not redirect_location:
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Mateo\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
