# %%
import requests
from bs4 import BeautifulSoup
import os

# %%
# url = "https://www.transfermarkt.es/vinotinto-fc/kader/verein/25958/saison_id/2024/plus/1"
# url = "https://www.transfermarkt.co/gimnasia-y-esgrima-de-mendoza/kader/verein/14687/saison_id/2024"
url = "https://www.transfermarkt.us/mamelodi-sundowns-fc/startseite/verein/6356"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "Accept-Language": "es-ES,es;q=0.9,en;q=0.8",
}

response = requests.get(url, headers=headers)
if response.status_code != 200:
    print(f"❌ Error al acceder a la página. Código: {response.status_code}")
    exit()

# %%
# soup = BeautifulSoup(response.text, "html.parser")
# output_folder = "imagenes_jugadores"
# os.makedirs(output_folder, exist_ok=True)

# # Buscar cada fila de jugador en la tabla
# rows = soup.select("table.items tbody tr")

# for row in rows:
#     img_tag = row.select_one("img.bilderrahmen-fixed")
#     name_tag = row.select_one("td.hauptlink a")
#     country_tag = row.select_one("td.zentriert img.flaggenrahmen")

#     if img_tag and name_tag and country_tag:
#         img_url = img_tag["data-src"].split("?")[0]  # Limpiar query
#         player_name = name_tag.text.strip()
#         country = country_tag["alt"].upper().replace(" ", "_")
#         name = player_name.upper().replace(" ", "_")

#         filename = f"{country}_{name}.png"
#         filepath = os.path.join("imagenes_jugadores", filename)

#         # Descargar la imagen
#         response = requests.get(img_url)
#         if response.status_code == 200:
#             with open(filepath, "wb") as f:
#                 f.write(response.content)
#             print(f"Guardado: {filename}")
#         else:
#             print(f"No se pudo descargar: {img_url}")

# %%
soup = BeautifulSoup(response.text, "html.parser")
output_folder = "imagenes_jugadores"
os.makedirs(output_folder, exist_ok=True)

# Buscar cada fila de jugador en la tabla
rows = soup.select("table.items tbody tr")

for row in rows:
    img_tag = row.select_one("img.bilderrahmen-fixed")
    name_tag = row.select_one("td.hauptlink a")
    country_tag = row.select_one("td.zentriert img.flaggenrahmen")

    if img_tag and name_tag and country_tag:
        img_url = img_tag["data-src"].split("?")[0]  # Limpiar query
        player_name = name_tag.text.strip()
        country = country_tag["alt"].upper().replace(" ", "_")

        # Procesar nombre: ALAN AGUIRRE → A_AGUIRRE
        name_parts = player_name.strip().upper().split()
        if len(name_parts) >= 2:
            name_formatted = f"{name_parts[0][0]}_{name_parts[-1]}"
        else:
            name_formatted = name_parts[0]

        filename = f"{country}_{name_formatted}.png"
        filepath = os.path.join(output_folder, filename)

        # Descargar la imagen
        response = requests.get(img_url)
        if response.status_code == 200:
            with open(filepath, "wb") as f:
                f.write(response.content)
            print(f"Guardado: {filename}")
        else:
            print(f"No se pudo descargar: {img_url}")
# Out:
# Guardado: SOUTH_AFRICA_R_WILLIAMS.png
# Guardado: UGANDA_I_WATENGA.png
# Guardado: SOUTH_AFRICA_J_FEBRUARY.png
# Guardado: UGANDA_D_ONYANGO.png
# Guardado: SOUTH_AFRICA_R_PIETERSE.png
# Guardado: SOUTH_AFRICA_M_MVALA.png
# Guardado: SOUTH_AFRICA_K_CUPIDO.png
# Guardado: SOUTH_AFRICA_M_KHOZA.png
# Guardado: SOUTH_AFRICA_G_KEKANA.png
# Guardado: SOUTH_AFRICA_M_LEBUSA.png
# Guardado: SOUTH_AFRICA_A_MODIBA.png
# Guardado: SOUTH_AFRICA_F_BASADIEN.png
# Guardado: ZIMBABWE_D_LUNGA.png
# Guardado: SOUTH_AFRICA_A_TIWANI.png
# Guardado: SOUTH_AFRICA_K_MUDAU.png
# Guardado: SOUTH_AFRICA_T_MORENA.png
# Guardado: SOUTH_AFRICA_K_JOHANNES.png
# Guardado: SOUTH_AFRICA_Z_MDUNYELWA.png
# Guardado: SOUTH_AFRICA_T_MOKOENA.png
# Guardado: SOUTH_AFRICA_B_AUBAAS.png
# Guardado: SOUTH_AFRICA_G_KEKANA.png
# Guardado: PORTUGAL_M_REISINHO.png
# Guardado: PORTUGAL_N_SANTOS.png
# Guardado: CHILE_M_ALLENDE.png
# Guardado: SOUTH_AFRICA_J_ADAMS.png
# Guardado: SOUTH_AFRICA_S_MKHULISE.png
# Guardado: SOUTH_AFRICA_T_NTSABELENG.png
# Guardado: SOUTH_AFRICA_T_ZWANE.png
# Guardado: SOUTH_AFRICA_T_MATTHEWS.png
# Guardado: SOUTH_AFRICA_T_MASEKO.png
# Guardado: ETHIOPIA_A_NASIR.png
# Guardado: SOUTH_AFRICA_S_MABENA.png
# Guardado: SOUTH_AFRICA_K_LETHLAKU.png
# Guardado: SOUTH_AFRICA_I_RAYNERS.png
# Guardado: NAMIBIA_P_SHALULILE.png
# Guardado: SOUTH_AFRICA_L_MOTHIBA.png
# Guardado: BRAZIL_A_SALES.png
